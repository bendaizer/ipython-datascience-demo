# %%
import tweepy
import json
import nltk
import gensim

# %%
conf = json.load(open("twitter.conf"))

consumer_key = conf["consumer_key"]
consumer_secret = conf["consumer_secret"]

access_token = conf["access_token"]
access_token_secret = conf["access_token_secret"]

# %% [markdown]
# ## twitter OAuth consumer

# %%
auth = tweepy.auth.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
data =[]

# %%
count = 0
for status in tweepy.Cursor(api.search, q="big data", count = 20,
                result_type="recent", include_entities=True).pages():
    count += 1
    if count >= 200 : 
        break 
    
    data.append(status[0].text.encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-9db3d073e56e> in <module>()
#       1 count = 0
#       2 for status in tweepy.Cursor(api.search, q="big data", count = 20,
# ----> 3                 result_type="recent", include_entities=True).pages():
#       4     count += 1
#       5     if count >= 200 :
#
# /Users/abenhenni/anaconda/lib/python2.7/site-packages/tweepy/cursor.pyc in next(self)
#      97
#      98         if self.index >= len(self.results) - 1:
# ---> 99             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     100
#     101             old_parser = self.method.__self__.parser
#
# /Users/abenhenni/anaconda/lib/python2.7/site-packages/tweepy/binder.pyc in _call(api, *args, **kargs)
#     228             return method
#     229         else:
# --> 230             return method.execute()
#     231
#     232     # Set pagination mode
#
# /Users/abenhenni/anaconda/lib/python2.7/site-packages/tweepy/binder.pyc in execute(self)
#     166                 # Execute request
#     167                 try:
# --> 168                     conn.request(self.method, url, headers=self.headers, body=self.post_data)
#     169                     resp = conn.getresponse()
#     170                 except Exception as e:
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#     993     def request(self, method, url, body=None, headers={}):
#     994         """Send a complete request to the server."""
# --> 995         self._send_request(method, url, body, headers)
#     996
#     997     def _set_content_length(self, body):
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1027         for hdr, value in headers.iteritems():
#    1028             self.putheader(hdr, value)
# -> 1029         self.endheaders(body)
#    1030
#    1031     def getresponse(self, buffering=False):
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#     989         else:
#     990             raise CannotSendHeader()
# --> 991         self._send_output(message_body)
#     992
#     993     def request(self, method, url, body=None, headers={}):
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     842             msg += message_body
#     843             message_body = None
# --> 844         self.send(msg)
#     845         if message_body is not None:
#     846             #message_body was not a string (i.e. it is a file) and
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in send(self, data)
#     804         if self.sock is None:
#     805             if self.auto_open:
# --> 806                 self.connect()
#     807             else:
#     808                 raise NotConnected()
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/httplib.pyc in connect(self)
#    1196                 self.sock = sock
#    1197                 self._tunnel()
# -> 1198             self.sock = ssl.wrap_socket(sock, self.key_file, self.cert_file)
#    1199
#    1200     __all__.append("HTTPSConnection")
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/ssl.pyc in wrap_socket(sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, suppress_ragged_eofs, ciphers)
#     390                      do_handshake_on_connect=do_handshake_on_connect,
#     391                      suppress_ragged_eofs=suppress_ragged_eofs,
# --> 392                      ciphers=ciphers)
#     393
#     394
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/ssl.pyc in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, suppress_ragged_eofs, ciphers)
#     146                                         ciphers)
#     147             if do_handshake_on_connect:
# --> 148                 self.do_handshake()
#     149         self.keyfile = keyfile
#     150         self.certfile = certfile
#
# /Users/abenhenni/anaconda/python.app/Contents/lib/python2.7/ssl.pyc in do_handshake(self)
#     308         """Perform a TLS/SSL handshake."""
#     309
# --> 310         self._sslobj.do_handshake()
#     311
#     312     def _real_connect(self, addr, return_errno):
#
# KeyboardInterrupt:

# %%
data
# Out:
# ['http://t.co/o3JkZjFOc9 - IBM  Big Data for Healthcare',
#  '#ANALYTICS has been trending 30min on the BIG DATA page http://t.co/5nRKYCcllz #Tweetzup',
#  'Using #Bigdata in #retail strategy. An example from #OilAndGas with Sunoco and Petro-Canada. http://t.co/SLrFVstV1V',
#  'RT @DARPA: MT @FCWnow: @DARPA is soliciting science and new mathematical models to connect the dots in big data http://t.co/yoH3XzxFjF',
#  'RT @MarcWilczek: #BigData Sprucing Up Enterprise Decision Making http://t.co/9ovn471uHc',
#  'The Influences of Big Data Analytics https://t.co/r3ZFMizvjQ',
#  '#Job #Arlington Senior Big Data Engineer (remote accepted): Washington LivingSocial is the local marketplace t... http://t.co/hBXbXFscgQ',
#  'Big Data Ingestion got you down? I N F O R M A T I C A spells relief http://t.co/S5ngMxKXBz #BigData',
#  'RT @yhemanth: A somewhat complete overview towards building a Hadoop based big data architecture focusing more on batch: http://t.co/Bukcta\xe2\x80\xa6',
#  'Big Data: 20 Free Big Data Sources Everyone Should Know http://t.co/JcgxXC9q3p',
#  'RT @DataRefinery: 89% of companies with #BigData XP say that is very \nimportant to their transformation \ninto digital http://t.co/rVuw1k82ht',
#  "Le Big Data n'est plus l'apanage de la DSI selon Forrester http://t.co/MPN4NHirVA",
#  'RT @StatisticsViews: Outlier Detection Gets a Makeover - Surprise Discovery in Scientific Big Data http://t.co/g0nctvYxHj',
#  "@frenchyballs I'm a big data sorta guy, I need evidence not to be redirected. Should be easy to supply if it's such a issue.",
#  'RT @chmielsoft: Zimoch nawo\xc5\x82uje do jab\xc5\x82ek na trybunach, a ja zdecydowanie wol\xc4\x99 jaki\xc5\x9b gest dla Go\xc5\x82asia. Dobra data na zwyci\xc4\x99stwo',
#  'How Big Data Could Discriminate: Where you live and shop, what you buy, how much you spend, and o... http://t.co/WXAV5HyK4P #Motherboard',
#  'http://t.co/ctgD71D9tn',
#  'RT @ZakriZAH: How Big Data Is Helping to Save the Planet http://t.co/zoDxaBMHyA @CIOonline @HP @ConservationOrg',
#  "RT @WitoldKepinski: IDC: 'Big data-markt groeit hard, maar de hype begint af te nemen' http://t.co/bk8GZiZrsI",
#  'L\xe2\x80\x99analisi dei Big Data di Twitter svela il sentiment dei turisti esteri nei confronti dell\xe2\x80\x99Italia http://t.co/IGuTidH8JM #iquii via @iquii',
#  'RT @UtopiaInc: "Unlocking the true potential of big data" http://t.co/1IpWRkoJrq by @TechRadarPro #bigdata http://t.co/LHdQSFBSTd',
#  'RT @YogeshMalik: Big Data  is out! http://t.co/GeLWNVb0y9 Stories via @sjtech8a @chrisdaleoxford @NextHire',
#  'Muji deploys cloud-based big data customer insights platform from Infosys http://t.co/NTlkBjBzYY',
#  'FTC warns of using big data to exclude consumers http://t.co/JC0dpdopJs']

# %%
import pickle

# %%
output = open("twitter.data", 'w')
pickle.dump(data, output)
output.close()

# %%
input = open("twitter.data", 'r')
p = pickle.Unpickler(input)
data_2 = p.load()
input.close()

data_2
# Out:
# ['http://t.co/o3JkZjFOc9 - IBM  Big Data for Healthcare',
#  '#ANALYTICS has been trending 30min on the BIG DATA page http://t.co/5nRKYCcllz #Tweetzup',
#  'Using #Bigdata in #retail strategy. An example from #OilAndGas with Sunoco and Petro-Canada. http://t.co/SLrFVstV1V',
#  'RT @DARPA: MT @FCWnow: @DARPA is soliciting science and new mathematical models to connect the dots in big data http://t.co/yoH3XzxFjF',
#  'RT @MarcWilczek: #BigData Sprucing Up Enterprise Decision Making http://t.co/9ovn471uHc',
#  'The Influences of Big Data Analytics https://t.co/r3ZFMizvjQ',
#  '#Job #Arlington Senior Big Data Engineer (remote accepted): Washington LivingSocial is the local marketplace t... http://t.co/hBXbXFscgQ',
#  'Big Data Ingestion got you down? I N F O R M A T I C A spells relief http://t.co/S5ngMxKXBz #BigData',
#  'RT @yhemanth: A somewhat complete overview towards building a Hadoop based big data architecture focusing more on batch: http://t.co/Bukcta\xe2\x80\xa6',
#  'Big Data: 20 Free Big Data Sources Everyone Should Know http://t.co/JcgxXC9q3p',
#  'RT @DataRefinery: 89% of companies with #BigData XP say that is very \nimportant to their transformation \ninto digital http://t.co/rVuw1k82ht',
#  "Le Big Data n'est plus l'apanage de la DSI selon Forrester http://t.co/MPN4NHirVA",
#  'RT @StatisticsViews: Outlier Detection Gets a Makeover - Surprise Discovery in Scientific Big Data http://t.co/g0nctvYxHj',
#  "@frenchyballs I'm a big data sorta guy, I need evidence not to be redirected. Should be easy to supply if it's such a issue.",
#  'RT @chmielsoft: Zimoch nawo\xc5\x82uje do jab\xc5\x82ek na trybunach, a ja zdecydowanie wol\xc4\x99 jaki\xc5\x9b gest dla Go\xc5\x82asia. Dobra data na zwyci\xc4\x99stwo',
#  'How Big Data Could Discriminate: Where you live and shop, what you buy, how much you spend, and o... http://t.co/WXAV5HyK4P #Motherboard',
#  'http://t.co/ctgD71D9tn',
#  'RT @ZakriZAH: How Big Data Is Helping to Save the Planet http://t.co/zoDxaBMHyA @CIOonline @HP @ConservationOrg',
#  "RT @WitoldKepinski: IDC: 'Big data-markt groeit hard, maar de hype begint af te nemen' http://t.co/bk8GZiZrsI",
#  'L\xe2\x80\x99analisi dei Big Data di Twitter svela il sentiment dei turisti esteri nei confronti dell\xe2\x80\x99Italia http://t.co/IGuTidH8JM #iquii via @iquii',
#  'RT @UtopiaInc: "Unlocking the true potential of big data" http://t.co/1IpWRkoJrq by @TechRadarPro #bigdata http://t.co/LHdQSFBSTd',
#  'RT @YogeshMalik: Big Data  is out! http://t.co/GeLWNVb0y9 Stories via @sjtech8a @chrisdaleoxford @NextHire',
#  "Here's why our new @gluster and big data community manager @dwmcallister decided to join #RedHat: http://t.co/SdJynnoYcK",
#  'Video: The Next Frontier for Big Data | WIRED http://t.co/IUJJJpdGaI',
#  "RT @salamingia: No thanks, I'll take the unlimited data but with no minutes.",
#  'RT @LHImag: #BigData: What does it mean for the #hospitalityindustry, and how we can leverage it? http://t.co/mJn4cp0Xsq',
#  'Big data al servizio dell\xe2\x80\x99Africa. (O no?)  http://t.co/BDIbwPouE3',
#  'RT @GroupM_Espana: No os perd\xc3\xa1is el estudio Big Success with #bigdata (v\xc3\xada @AccentureDigi) http://t.co/9ienVLEoQ1',
#  'MapR Ships Drill For SQL Analysis Of Big Data - InformationWeek http://t.co/UhpsvdXPIH',
#  '7 tendencias IT: cloud, seguridad, vos en tiempo real (VoIP), IoT, contenido en todo lugar, Big Data y SDE #ForoLevel3',
#  'RT @SmartDataCo: 3 #BigData Use Cases to Kickstart Your #Data-Driven Initiatives. @tracewall http://t.co/Md94ubJ4TT',
#  'What is Big Data?: http://t.co/3f9qj4wgsi via @YouTube',
#  'Big Data - Projektvorstellung am 18. Sept. in Wiesbaden. Agenda + Details unter: http://t.co/6iXa1tIWLf  #bigdata #flash #storage',
#  'Can the FTC protect consumers from the big data paradox? http://t.co/R3m8XP4toJ',
#  'How Big Data Could Discriminate: Where you live and shop, what you buy, how much you spend, and ot... http://t.co/FemsLZjN6W #Hacktivism',
#  'Join us today (9/16) at noon @AssnMediaPub http://t.co/y7Fbp36q8q  cc: @sehadden @joecolangelo #assnchat',
#  'Aspera, an IBM Company, Unveils Expanded On Demand Transfer Platform for Big Data #ibm http://t.co/mIhlzvxtvu',
#  'RT @JesusSagospe: \xe2\x80\x98Big data\xe2\x80\x99, un mercado multimillonario http://t.co/GhN9ZI9rp5',
#  'RT @PuzzlesRemember: Using big data to fight dementia and Alzheimer\xe2\x80\x99s http://t.co/J1OfCX8WcT',
#  'RT @ksliechti: What Baseball Teaches Us About Big Data. Turns out quite a bit. #bigData #IBM http://t.co/sZB3vJbz08',
#  'What have companies learned about #bigdata implementation? http://t.co/SeD036Aov5',
#  'RT @BigDataBlogs: BigData \xc2\xbb Four Big Data Use Cases from the Media and Publishing Industry: BBC, http://t.co/C6VbSAetOw ... http://t.co/39y\xe2\x80\xa6',
#  'RT @DESSCecotech: How #BigData Helps #Water Management, via @ELDaily: http://t.co/XMJ4zZIBpi',
#  'gegenstimmen zu #bigdata #perspektivenwechsel http://t.co/s1wHKu0Fpz',
#  '@AnalyticsCrunch Expanded in this book: The Influences of Big Data Analytics https://t.co/r3ZFMizvjQ \xe2\x80\xa6t',
#  'RT @ComputingOviedo: Conferencias sobre Big Data y seguridad el pr\xc3\xb3ximo jueves 18 entre las 17 y las 20 horas. M\xc3\xa1s info: http://t.co/lIAp5W\xe2\x80\xa6',
#  "WHY BIG DATA\nA complete view with Case Studies, kind of Jobs &amp; Salaries, What is Big data &amp; it's real life Importanc\xe2\x80\xa6http://t.co/2IzlcmKLSE",
#  '#BigData is helping to save the planet #Data #Analytics #GreenIT  http://t.co/PRPtXTQxY8',
#  'RT @SuccessPros: IBM Covers the Board for Big Data Solutions: IBM STG (the hardware group) will tell you infrastructur... http://t.co/I563N\xe2\x80\xa6',
#  'O que \xc3\xa9 big data e como usar na sua pequena empresa: Descubra os principais passos para ter Big Data no seu ne...  http://t.co/JW52lxmDUV',
#  'RT @jenstirrup: Top story: Drone Data Adds a New Horizon for Big Data Analytics http://t.co/yAbkPbjKME, see more http://t.co/OHbAivyCeG',
#  'RT @Jess_Reif: how #bigdata can improve decision making in healthcare http://t.co/YiMXhZbX25',
#  '"Upcoming Webcasts on Analytics, Big Data, Data Science \xe2\x80\x93 Sep 16 and beyond" #webcast #bigdata #follow http://t.co/aDYjxwjShd',
#  'RT @IBMbigdata: Video: The next frontier for #BigData http://t.co/NbogCP2WBE via @Wired',
#  'FBI Facial Recognition System Operational http://t.co/pUQyBG9tq6',
#  'RT @agencypja: Who says you have to choose between big data and creative? http://t.co/61Xma1X2g5',
#  "RT @eB2B_Cloud: It's Not Just Big Data, It's The Right Big Data That Matters Most  http://t.co/inATyLHBMS #bigdata",
#  ". Big Bytes! Check out the U.S. Government's Data Explosion (Infographic) http://t.co/5ad1pPps21 via @wordpressdotcom http://t.co/anrnqFOc3L",
#  'Big Data Opportunities to Transform Cities \xe2\x80\x94 http://t.co/2PC68dajhr http://t.co/oLOVDBsVR9    #bigdata',
#  "RT @O_Berard: Le #BigData n'est plus l'apanage de la #DSI selon Forrester http://t.co/7j4fRDswFM par @bduperrin",
#  'Now, Digital Quotient will help brands to decode big data: Big data in marketing is getting its due with the... http://t.co/h9hjFAmfRF',
#  'New Surveys On Big Data, Big Decisions, Analysis, And Intuition - Two new reports on big data and big... http://t.co/U9Kudhlvyr',
#  'Check out this #job: #Software Development Manager: Big #Data and #Data Warehouse at #Amazon (#Seattle) http://t.co/fC9F2q0WYm',
#  'O que \xc3\xa9 big data e como usar na sua pequena empresa http://t.co/6MBbmka0IE',
#  'Measuring marketing and amplifying performance with big data (Slideshare)http://t.co/LCYbpNqeOq @IBMsocialbiz #TEDatIBM #bigdata',
#  'Big Data: A Change of Mindset http://t.co/7pT8co6YHP',
#  'GE will create 30 big data startups alongside an Orange County incubator http://t.co/NJeD59z2pf',
#  'Robin Prosch und Ralf Kaltenbach sprechen gleich \xc3\xbcber Big Data und Intelligence Driven Security #EMCForum http://t.co/1DpZfrQs19',
#  "#TechNewsAfrica Nigeria\xc3\xa2's Delivery Science Turns Big Data Around to Simplify Logisitics Management |... http://t.co/rglZ1D5DTM",
#  'Now everyone will know I cheat with potato chips! How Big Data Will Change the Way You Eat http://t.co/V9H1DQLPXP via @NatGeo',
#  '@npmulani, @segalink, @Qoints,@BillBrindley @saungseint @AnalyticsCrunch Thanks for sharing the book: The Influences of Big Data Analytics.',
#  'Trade Me Standardizes on Splunk Enterprise \xe2\x80\x9cTrade Me has created a business culture that uses big data in real t... http://t.co/v5oNctI8JV',
#  'Big up @EE refreshing my Internet data for month!',
#  'RT @SieJ24: Alt-J, Young the Giant, Bear hands, Fall Out Boy, Big Data, New Politics, Dirty Heads. \xf0\x9f\x99\x8c \xf0\x9f\x98\xbb\xf0\x9f\x91\x8c',
#  'RT @cc_ipg: BDMA Seminar on big data. IBM interviewed 1.700 Chief Marketing Officers. Advanced (=predictive) analytics will dominate future\xe2\x80\xa6',
#  "Our friend UsAgainstAlzheimer's @vradenburg3 on using big data to understand Alzheimer's: http://t.co/T0lKjKNcxk http://t.co/Wmhz1w2VWF",
#  'RT @TungstenBigData: IBM Covers the Board for Big Data Solutions http://t.co/oEhVnkmeCw #BigData',
#  'SQLstream Teradata http://t.co/pONuXH60o2 #BDE #InsideAnalysis @sqlstream',
#  'RT @CPGorinchem: Big data in communicatie: 23/9 vertelt @janwillem van @greenberrynl er alles over. Aanmelden kan via http://t.co/phgjMLna33',
#  'RT @BigDataNetwork: #BigData News \xc2\xbb Research and Markets: The Future of Big Data Analytics - Global Market and... http://t.co/r16w88ROqF vi\xe2\x80\xa6',
#  'At Big Data conference led by Swiss Re CEO Michel Lies \xe2\x80\x94 at Fairmont Monte Carlo http://t.co/W6oNy9vycF',
#  "Le Big Data : une r\xc3\xa9volution aussi importante que celle d'... http://t.co/LGR9k3RXlT",
#  'Most senior executives happy with results of #bigdata projects http://t.co/zfUGQy2m6P',
#  '@IDCSpain El 18 de Sept an\xc3\xa1lisis todo lo que debes saber sobre el #bigdata http://t.co/xPIhSMSrdt',
#  '#BigData News \xc2\xbb Research and Markets: The Future of Big Data Analytics - Global Market and... http://t.co/r16w88ROqF via @BigDataNetwork',
#  "Big data is 'marketing heaven', says IBM Europe CMO Caroline Taylor http://t.co/eH8APfjVC0 http://t.co/2E2FuZajTn",
#  'RT @DeloitteHealth: Check out 6 trends in the #bigdata revolution http://t.co/6pmhYl38M7 #NHITWeek http://t.co/RhC52PPoPy',
#  'Read &gt; http://t.co/c3vwVTr3Qm #56092 #kindle\n\nBig Data: A Revolution That Will Transform How We Live, Work, and... http://t.co/f9LmQxzXDU',
#  'RT @cheaphosting381: FTC warns of using big data to exclude consumers  http://t.co/iQdHrBueEF',
#  'Managing the big flood of big data https://t.co/Lld5RFbIr3 #analytics #bi',
#  'Preparing Your Data Warehouse Environment for Big Data https://t.co/WJt8P0kfng #analytics #data #bigdata',
#  "D\xc3\xa9couvrez de vrais cas d'usage Big Data http://t.co/B4HtHrCgWK @cabinet_solucom @vertone @BearingPoint_FR @ATKearney http://t.co/CSgwvOcYWu",
#  'Medical Calculators Use Big Data to Help Patients Make Choices: http://t.co/lQMDKYCIK1',
#  'RT @NatGeo: Will big data change the way you eat? http://t.co/sf6MgUZpXt #FutureofFood',
#  'RT @abonde: New video of me + @loiemaxwell discussing data, customer loyalty and the next big #app http://t.co/JcuAUYUflr #CX #analytics #B\xe2\x80\xa6',
#  'RT @CathCervoni "Les c\xc3\xa2bles sous-marins, enjeu strat\xc3\xa9gique du Big Data http://t.co/RGogOwNcP7 \xe2\x80\xa6 \xe2\x80\xa6 via @latelier"',
#  'How Can #bigdata Help Low-Income Students? \nhttp://t.co/eFvFnRs54q',
#  'San Diego Taps Big Data To Optimize Transit http://t.co/3ELRTsfiJS',
#  'RT @EFF: We need proof that big data is good science and not just snake oil: https://t.co/itv1lSxPfX',
#  'RT @BradfordBrown: FTC warns companies not to use big data to exclude consumers http://t.co/tYmCGnXqbP #bigdata',
#  'Muji deploys cloud-based big data customer insights platform from Infosys http://t.co/NTlkBjBzYY',
#  'FTC warns of using big data to exclude consumers http://t.co/JC0dpdopJs']
